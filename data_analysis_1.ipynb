# %%
import pandas as pd # as keyword is used to define an alias

# %%
url ="https://raw.githubusercontent.com/braincomputingsantosh/Data/master/chipotle.tsv.txt"
chipoDF = pd.read_csv(url, sep='\t')

# %%
chipoDF
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# List Comprehension

# %%
fruits = ['apple', 'banana', "cherry", "kiwi", "mango"]
newList = []
for x in fruits:
    if "a" in x:
        newList.append(x)
        
newList
# Out:
# ['apple', 'banana', 'mango']

# %%
# With List comprehension
newList = [x for x in fruits if "a" in x]
newList
# Out:
# ['apple', 'banana', 'mango']

# %% [markdown]
# Back to Chipotle Dataframes

# %%
# clean the item_price column and transform it in a float
prices = [float(value[1:-1]) for value in chipoDF.item_price]
#prices

# %%
# reassign the column with the cleaned prices
chipoDF.item_price = prices

# %%
# print the Dataframe to see the new cleaned price 
chipoDF
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
chipoDF_filtered = chipoDF.drop_duplicates(['item_name', 'quantity'])
#chipoDF_filtered

# %%
chipoDF_one_product = chipoDF_filtered[chipoDF_filtered.quantity == 1]
#chipoDF_one_product

# %%
# select only the products with quantity equals to 1
chipoDF_one_product = [chipoDF_filtered.quantity == 1]

# %%
chipoDF_one_product[chipoDF_one_product['item_price'] >10].item_name.nunique()
# Out:
# 12

# %%
# what is the price of each item?
# print a data frame only two columns, item_name and item_price
chipoDF_filtered = chipoDF.drop_duplicates(['item_name', 'quantity'])
# select only the products with quantity equals 1
chipoDF_one_product = chipoDF_filtered[chipoDF_filtered.quantity == 1]
#select only the item_name an item price columns
price_per_item = chipoDF_one_product[['item_name', 'item_price']]
# sort the values from the most to less expensive
price_per_item.sort_values(by="item_price", ascending=False).head(10)
# Out:
#                   item_name  item_price
# 606        Steak Salad Bowl       11.89
# 1229    Barbacoa Salad Bowl       11.89
# 1132    Carnitas Salad Bowl       11.89
# 7             Steak Burrito       11.75
# 168   Barbacoa Crispy Tacos       11.75
# 39            Barbacoa Bowl       11.75
# 738       Veggie Soft Tacos       11.25
# 186       Veggie Salad Bowl       11.25
# 62              Veggie Bowl       11.25
# 57           Veggie Burrito       11.25

# %%
chipoDF.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# ...

# %%
# sort by the name of the item
chipoDF.item_name.sort_values()
# Out:
# 3389    6 Pack Soft Drink
# 341     6 Pack Soft Drink
# 1849    6 Pack Soft Drink
# 1860    6 Pack Soft Drink
# 2713    6 Pack Soft Drink
#               ...
# 2384    Veggie Soft Tacos
# 781     Veggie Soft Tacos
# 2851    Veggie Soft Tacos
# 1699    Veggie Soft Tacos
# 1395    Veggie Soft Tacos
# Name: item_name, Length: 4622, dtype: object

# %%
chipoDF.sort_values(by = "item_name")
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 2384       948         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
# 2851      1132         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
#
#                                      choice_description  item_price
# 3389                                        [Diet Coke]       12.98
# 341                                         [Diet Coke]        6.49
# 1849                                             [Coke]        6.49
# 1860                                        [Diet Coke]        6.49
# 2713                                             [Coke]        6.49
# ...

# %%
# What was teh quantity of the most expensive item ordered
chipoDF.sort_values(by="item_price", ascending=False).head(1)
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598       44.25
